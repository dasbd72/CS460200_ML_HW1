# %% [markdown]
# (optional)

# %%
# from google.colab import drive
# import os
# drive.mount('/content/drive')

# %%
# os.chdir('...')

# %% [markdown]
# # **HW5: Brain signal classification**
# In *HW 5*, you need to finish:
#
# 1.  Model Implementation Part: Implement LSTM and EEGNet models to predict the label of each samples.
#
# 2.  Model Competition Part: Implementing a model to reach better accuracy performance.

# %%
import numpy as np
import os
import math
import csv
import matplotlib.pyplot as plt
# Import the packages you need here
import tensorflow as tf
import keras
from keras import layers, losses, activations, optimizers, metrics

# %%
data = np.load('data.npz')
label = np.load('label.npz')

# %%
X_train = data['X_train']
X_val = data['X_val']
X_test = data['X_test']

Y_train = label['Y_train']
Y_val = label['Y_val']

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((604, 22, 200), (152, 22, 200), (190, 22, 200))

# %%
Y_train.shape, Y_val.shape
# Out:
# ((604, 1), (152, 1))

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((604, 22, 200), (152, 22, 200), (190, 22, 200))

# %%
Y_train = np.eye(6)[Y_train.reshape(-1).astype(int)]
Y_val = np.eye(6)[Y_val.reshape(-1).astype(int)]
Y_train.shape, Y_val.shape
# Out:
# ((604, 6), (152, 6))

# %% [markdown]
# ## Model Implementation Part

# %% [markdown]
# ### LSTM

# %%
# Build your model here:
input_shape = (22, 200)
epochs = 20

lstm_model = keras.Sequential([
    layers.InputLayer(input_shape=input_shape),
    layers.LSTM(1000),
    layers.Dense(1000, activation='relu'),
    layers.Dense(6, activation='softmax'),
])

lstm_model.summary()
# Out:
# Metal device set to: Apple M2
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2022-12-27 18:20:00.222766: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-12-27 18:20:00.222872: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1000)              4804000
#
#  dense (Dense)               (None, 1000)              1001000
#
#  dense_1 (Dense)             (None, 6)                 6006
#
# =================================================================
# Total params: 5,811,006
# Trainable params: 5,811,006
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.compile(
    optimizer=optimizers.RMSprop(),
    loss=losses.CategoricalCrossentropy(),
    metrics=[metrics.CategoricalAccuracy()]
)
history = lstm_model.fit(X_train, Y_train, epochs=epochs, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/20
# 2022-12-27 18:20:00.958304: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-12-27 18:20:01.833044: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-27 18:20:02.001310: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-27 18:20:02.187001: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 19/19 [==============================] - ETA: 0s - loss: 1.4788 - categorical_accuracy: 0.5132
# 2022-12-27 18:20:03.497042: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-27 18:20:03.549262: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 19/19 [==============================] - 3s 74ms/step - loss: 1.4788 - categorical_accuracy: 0.5132 - val_loss: 0.6833 - val_categorical_accuracy: 0.7039
# Epoch 2/20
# 19/19 [==============================] - 1s 48ms/step - loss: 0.4549 - categorical_accuracy: 0.8262 - val_loss: 0.6298 - val_categorical_accuracy: 0.7697
# Epoch 3/20
# 19/19 [==============================] - 1s 48ms/step - loss: 0.1662 - categorical_accuracy: 0.9470 - val_loss: 0.6900 - val_categorical_accuracy: 0.7632
# Epoch 4/20
# 19/19 [==============================] - 1s 47ms/step - loss: 0.0434 - categorical_accuracy: 0.9901 - val_loss: 0.4344 - val_categorical_accuracy: 0.8618
# Epoch 5/20
# 19/19 [==============================] - 1s 47ms/step - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 0.4405 - val_categorical_accuracy: 0.8684
# Epoch 6/20
# 19/19 [==============================] - 1s 48ms/step - loss: 3.3550e-04 - categorical_accuracy: 1.0000 - val_loss: 0.4501 - val_categorical_accuracy: 0.8750
# Epoch 7/20
# 19/19 [==============================] - 1s 47ms/step - loss: 1.0491e-04 - categorical_accuracy: 1.0000 - val_loss: 0.4790 - val_categorical_accuracy: 0.8750
# Epoch 8/20
# 19/19 [==============================] - 1s 47ms/step - loss: 3.2509e-05 - categorical_accuracy: 1.0000 - val_loss: 0.5049 - val_categorical_accuracy: 0.8750
# Epoch 9/20
# 19/19 [==============================] - 1s 48ms/step - loss: 1.0199e-05 - categorical_accuracy: 1.0000 - val_loss: 0.5204 - val_categorical_accuracy: 0.8816
# Epoch 10/20
# 19/19 [==============================] - 1s 48ms/step - loss: 3.4163e-06 - categorical_accuracy: 1.0000 - val_loss: 0.5497 - val_categorical_accuracy: 0.8750
# Epoch 11/20
# 19/19 [==============================] - 1s 48ms/step - loss: 1.2310e-06 - categorical_accuracy: 1.0000 - val_loss: 0.5877 - val_categorical_accuracy: 0.8684
# Epoch 12/20
# 19/19 [==============================] - 1s 47ms/step - loss: 4.8360e-07 - categorical_accuracy: 1.0000 - val_loss: 0.6019 - val_categorical_accuracy: 0.8750
# Epoch 13/20
# 19/19 [==============================] - 1s 47ms/step - loss: 2.1396e-07 - categorical_accuracy: 1.0000 - val_loss: 0.6255 - val_categorical_accuracy: 0.8750
# Epoch 14/20
# 19/19 [==============================] - 1s 47ms/step - loss: 1.0972e-07 - categorical_accuracy: 1.0000 - val_loss: 0.6399 - val_categorical_accuracy: 0.8750
# Epoch 15/20
# 19/19 [==============================] - 1s 47ms/step - loss: 6.0331e-08 - categorical_accuracy: 1.0000 - val_loss: 0.6500 - val_categorical_accuracy: 0.8816
# Epoch 16/20
# 19/19 [==============================] - 1s 48ms/step - loss: 2.7087e-08 - categorical_accuracy: 1.0000 - val_loss: 0.6581 - val_categorical_accuracy: 0.8816
# Epoch 17/20
# 19/19 [==============================] - 1s 48ms/step - loss: 1.5185e-08 - categorical_accuracy: 1.0000 - val_loss: 0.6610 - val_categorical_accuracy: 0.8816
# Epoch 18/20
# 19/19 [==============================] - 1s 47ms/step - loss: 6.7034e-09 - categorical_accuracy: 1.0000 - val_loss: 0.6666 - val_categorical_accuracy: 0.8750
# Epoch 19/20
# 19/19 [==============================] - 1s 47ms/step - loss: 3.2833e-09 - categorical_accuracy: 1.0000 - val_loss: 0.6659 - val_categorical_accuracy: 0.8750
# Epoch 20/20
# 19/19 [==============================] - 1s 47ms/step - loss: 2.4625e-09 - categorical_accuracy: 1.0000 - val_loss: 0.6671 - val_categorical_accuracy: 0.8816

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(loc='upper right')

# %%
output = np.argmax(lstm_model.predict(X_test), axis=1).reshape(-1, 1)
assert(output.shape == (190, 1))
np.savetxt('lstm_output.csv', output, delimiter=",")
# Out:
# 4/6 [===================>..........] - ETA: 0s
# 2022-12-27 18:20:21.207374: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-27 18:20:21.246739: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 6/6 [==============================] - 0s 24ms/step

# %% [markdown]
# ### EEGNet

# %%
# Build your model here:
channels = 22
timePoints = 200
F1 = 8
F2 = 16
depth = 2
epochs = 40

eegnet_model = keras.Sequential([
    layers.InputLayer(input_shape=(channels, timePoints)),
    layers.Reshape((channels, timePoints, 1)),
    layers.Conv2D(F1, (1, 64), padding='same', use_bias=False),
    layers.BatchNormalization(axis = 1),
    layers.DepthwiseConv2D((channels, 1), use_bias = False, depth_multiplier = depth, depthwise_constraint = tf.keras.constraints.max_norm(1.)),
    layers.BatchNormalization(axis = 1),
    layers.Activation('elu'),
    layers.AveragePooling2D((1, 4)),
    layers.Dropout(0.25),
    layers.SeparableConv2D(F2, (1, 16), padding='same', use_bias=False),
    layers.BatchNormalization(axis = 1),
    layers.Activation('elu'),
    layers.AveragePooling2D((1, 8)),
    layers.Dropout(0.25),
    layers.Flatten(name = 'flatten'),
    layers.Dense(6, activation='softmax', name='dense', kernel_constraint = tf.keras.constraints.max_norm(.25)),
])

eegnet_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 22, 200, 1)        0
#
#  conv2d (Conv2D)             (None, 22, 200, 8)        512
#
#  batch_normalization (BatchN  (None, 22, 200, 8)       88
#  ormalization)
#
#  depthwise_conv2d (Depthwise  (None, 1, 200, 16)       352
#  Conv2D)
#
#  batch_normalization_1 (Batc  (None, 1, 200, 16)       4
#  hNormalization)
#
#  activation (Activation)     (None, 1, 200, 16)        0
#
#  average_pooling2d (AverageP  (None, 1, 50, 16)        0
#  ooling2D)
#
#  dropout (Dropout)           (None, 1, 50, 16)         0
#
#  separable_conv2d (Separable  (None, 1, 50, 16)        512
#  Conv2D)
#
#  batch_normalization_2 (Batc  (None, 1, 50, 16)        4
#  hNormalization)
#
#  activation_1 (Activation)   (None, 1, 50, 16)         0
#
#  average_pooling2d_1 (Averag  (None, 1, 6, 16)         0
#  ePooling2D)
#
#  dropout_1 (Dropout)         (None, 1, 6, 16)          0
#
#  flatten (Flatten)           (None, 96)                0
#
#  dense (Dense)               (None, 6)                 582
#
# =================================================================
# Total params: 2,054
# Trainable params: 2,006
# Non-trainable params: 48
# _________________________________________________________________

# %%
eegnet_model.compile(
    optimizer=optimizers.RMSprop(),
    loss=losses.CategoricalCrossentropy(),
    metrics=[metrics.CategoricalAccuracy()]
)
history = eegnet_model.fit(X_train, Y_train, epochs=epochs, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/40
# 2022-12-27 18:20:22.008391: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 19/19 [==============================] - 2s 47ms/step - loss: 1.6112 - categorical_accuracy: 0.5033 - val_loss: 1.6509 - val_categorical_accuracy: 0.5987
# Epoch 2/40
#  1/19 [>.............................] - ETA: 0s - loss: 1.4231 - categorical_accuracy: 0.6250
# 2022-12-27 18:20:23.143480: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 19/19 [==============================] - 1s 32ms/step - loss: 1.3237 - categorical_accuracy: 0.7053 - val_loss: 1.5577 - val_categorical_accuracy: 0.7566
# Epoch 3/40
# 19/19 [==============================] - 1s 32ms/step - loss: 1.1293 - categorical_accuracy: 0.8113 - val_loss: 1.4059 - val_categorical_accuracy: 0.8026
# Epoch 4/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.9924 - categorical_accuracy: 0.8510 - val_loss: 1.2853 - val_categorical_accuracy: 0.8684
# Epoch 5/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.9030 - categorical_accuracy: 0.8692 - val_loss: 1.1741 - val_categorical_accuracy: 0.8882
# Epoch 6/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.8378 - categorical_accuracy: 0.9007 - val_loss: 1.0728 - val_categorical_accuracy: 0.9013
# Epoch 7/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.7913 - categorical_accuracy: 0.8990 - val_loss: 0.9717 - val_categorical_accuracy: 0.9079
# Epoch 8/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.7671 - categorical_accuracy: 0.8990 - val_loss: 0.9163 - val_categorical_accuracy: 0.9013
# Epoch 9/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.7308 - categorical_accuracy: 0.9189 - val_loss: 0.8363 - val_categorical_accuracy: 0.9145
# Epoch 10/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.7016 - categorical_accuracy: 0.9305 - val_loss: 0.7992 - val_categorical_accuracy: 0.9145
# Epoch 11/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.6772 - categorical_accuracy: 0.9205 - val_loss: 0.7593 - val_categorical_accuracy: 0.9211
# Epoch 12/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.6575 - categorical_accuracy: 0.9338 - val_loss: 0.7330 - val_categorical_accuracy: 0.9145
# Epoch 13/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.6429 - categorical_accuracy: 0.9222 - val_loss: 0.6885 - val_categorical_accuracy: 0.9211
# Epoch 14/40
# 19/19 [==============================] - 1s 34ms/step - loss: 0.6262 - categorical_accuracy: 0.9454 - val_loss: 0.6495 - val_categorical_accuracy: 0.9342
# Epoch 15/40
# 19/19 [==============================] - 1s 33ms/step - loss: 0.5955 - categorical_accuracy: 0.9536 - val_loss: 0.6332 - val_categorical_accuracy: 0.9408
# Epoch 16/40
# 19/19 [==============================] - 1s 31ms/step - loss: 0.5814 - categorical_accuracy: 0.9536 - val_loss: 0.6155 - val_categorical_accuracy: 0.9408
# Epoch 17/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.5746 - categorical_accuracy: 0.9570 - val_loss: 0.5727 - val_categorical_accuracy: 0.9408
# Epoch 18/40
# 19/19 [==============================] - 1s 33ms/step - loss: 0.5463 - categorical_accuracy: 0.9669 - val_loss: 0.5736 - val_categorical_accuracy: 0.9408
# Epoch 19/40
# 19/19 [==============================] - 1s 34ms/step - loss: 0.5356 - categorical_accuracy: 0.9570 - val_loss: 0.5476 - val_categorical_accuracy: 0.9539
# Epoch 20/40
# 19/19 [==============================] - 1s 31ms/step - loss: 0.5214 - categorical_accuracy: 0.9536 - val_loss: 0.5013 - val_categorical_accuracy: 0.9474
# Epoch 21/40
# 19/19 [==============================] - 1s 31ms/step - loss: 0.5016 - categorical_accuracy: 0.9719 - val_loss: 0.4832 - val_categorical_accuracy: 0.9474
# Epoch 22/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.4943 - categorical_accuracy: 0.9702 - val_loss: 0.4911 - val_categorical_accuracy: 0.9605
# Epoch 23/40
# 19/19 [==============================] - 1s 31ms/step - loss: 0.4723 - categorical_accuracy: 0.9636 - val_loss: 0.4700 - val_categorical_accuracy: 0.9539
# Epoch 24/40
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4697 - categorical_accuracy: 0.9636 - val_loss: 0.4326 - val_categorical_accuracy: 0.9605
# Epoch 25/40
# 19/19 [==============================] - 1s 36ms/step - loss: 0.4549 - categorical_accuracy: 0.9719 - val_loss: 0.4411 - val_categorical_accuracy: 0.9605
# Epoch 26/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.4473 - categorical_accuracy: 0.9685 - val_loss: 0.4219 - val_categorical_accuracy: 0.9605
# Epoch 27/40
# 19/19 [==============================] - 1s 31ms/step - loss: 0.4319 - categorical_accuracy: 0.9702 - val_loss: 0.4036 - val_categorical_accuracy: 0.9605
# Epoch 28/40
# 19/19 [==============================] - 1s 33ms/step - loss: 0.4190 - categorical_accuracy: 0.9685 - val_loss: 0.4173 - val_categorical_accuracy: 0.9605
# Epoch 29/40
# 19/19 [==============================] - 1s 34ms/step - loss: 0.4155 - categorical_accuracy: 0.9685 - val_loss: 0.3908 - val_categorical_accuracy: 0.9605
# Epoch 30/40
# 19/19 [==============================] - 1s 34ms/step - loss: 0.3965 - categorical_accuracy: 0.9735 - val_loss: 0.3657 - val_categorical_accuracy: 0.9671
# Epoch 31/40
# 19/19 [==============================] - 1s 35ms/step - loss: 0.3885 - categorical_accuracy: 0.9669 - val_loss: 0.3653 - val_categorical_accuracy: 0.9605
# Epoch 32/40
# 19/19 [==============================] - 1s 33ms/step - loss: 0.3724 - categorical_accuracy: 0.9735 - val_loss: 0.3350 - val_categorical_accuracy: 0.9671
# Epoch 33/40
# 19/19 [==============================] - 1s 33ms/step - loss: 0.3749 - categorical_accuracy: 0.9735 - val_loss: 0.3224 - val_categorical_accuracy: 0.9671
# Epoch 34/40
# 19/19 [==============================] - 1s 33ms/step - loss: 0.3626 - categorical_accuracy: 0.9768 - val_loss: 0.3268 - val_categorical_accuracy: 0.9671
# Epoch 35/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.3531 - categorical_accuracy: 0.9719 - val_loss: 0.3201 - val_categorical_accuracy: 0.9671
# Epoch 36/40
# 19/19 [==============================] - 1s 31ms/step - loss: 0.3456 - categorical_accuracy: 0.9768 - val_loss: 0.3048 - val_categorical_accuracy: 0.9605
# Epoch 37/40
# 19/19 [==============================] - 1s 30ms/step - loss: 0.3356 - categorical_accuracy: 0.9768 - val_loss: 0.2940 - val_categorical_accuracy: 0.9671
# Epoch 38/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.3318 - categorical_accuracy: 0.9685 - val_loss: 0.2909 - val_categorical_accuracy: 0.9671
# Epoch 39/40
# 19/19 [==============================] - 1s 30ms/step - loss: 0.3248 - categorical_accuracy: 0.9752 - val_loss: 0.3033 - val_categorical_accuracy: 0.9671
# Epoch 40/40
# 19/19 [==============================] - 1s 32ms/step - loss: 0.3129 - categorical_accuracy: 0.9768 - val_loss: 0.2974 - val_categorical_accuracy: 0.9605

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(loc='upper right')

# %%
output = np.argmax(eegnet_model.predict(X_test), axis=1).reshape(-1, 1)
assert(output.shape == (190, 1))
np.savetxt('eegnet_output.csv', output, delimiter=",")
# Out:
# 6/6 [==============================] - 0s 11ms/step
# 2022-12-27 18:20:47.319214: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# ## Model Competition Part

# %%
# Build your model here:
channels = 22
timePoints = 200
F1 = 64
F2 = 128
depth = 2
epochs = 40

model = keras.Sequential([
    layers.InputLayer(input_shape=(channels, timePoints)),
    layers.Reshape((channels, timePoints, 1)),
    layers.Conv2D(F1, (1, 64), padding='same', use_bias=False),
    layers.BatchNormalization(axis = 1),
    layers.DepthwiseConv2D((channels, 1), use_bias = False, depth_multiplier = depth, depthwise_constraint = tf.keras.constraints.max_norm(1.)),
    layers.BatchNormalization(axis = 1),
    layers.Activation('elu'),
    layers.AveragePooling2D((1, 4)),
    layers.Dropout(0.25),
    layers.SeparableConv2D(F2, (1, 16), padding='same', use_bias=False),
    layers.BatchNormalization(axis = 1),
    layers.Activation('elu'),
    layers.AveragePooling2D((1, 8)),
    layers.Dropout(0.25),
    layers.Flatten(name = 'flatten'),
    layers.Dense(6, activation='softmax', name='dense', kernel_constraint = tf.keras.constraints.max_norm(.25)),
])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_1 (Reshape)         (None, 22, 200, 1)        0
#
#  conv2d_1 (Conv2D)           (None, 22, 200, 64)       4096
#
#  batch_normalization_3 (Batc  (None, 22, 200, 64)      88
#  hNormalization)
#
#  depthwise_conv2d_1 (Depthwi  (None, 1, 200, 128)      2816
#  seConv2D)
#
#  batch_normalization_4 (Batc  (None, 1, 200, 128)      4
#  hNormalization)
#
#  activation_2 (Activation)   (None, 1, 200, 128)       0
#
#  average_pooling2d_2 (Averag  (None, 1, 50, 128)       0
#  ePooling2D)
#
#  dropout_2 (Dropout)         (None, 1, 50, 128)        0
#
#  separable_conv2d_1 (Separab  (None, 1, 50, 128)       18432
#  leConv2D)
#
#  batch_normalization_5 (Batc  (None, 1, 50, 128)       4
#  hNormalization)
#
#  activation_3 (Activation)   (None, 1, 50, 128)        0
#
#  average_pooling2d_3 (Averag  (None, 1, 6, 128)        0
#  ePooling2D)
#
#  dropout_3 (Dropout)         (None, 1, 6, 128)         0
#
#  flatten (Flatten)           (None, 768)               0
#
#  dense (Dense)               (None, 6)                 4614
#
# =================================================================
# Total params: 30,054
# Trainable params: 30,006
# Non-trainable params: 48
# _________________________________________________________________

# %%
model.compile(
    optimizer=optimizers.RMSprop(),
    loss=losses.CategoricalCrossentropy(),
    metrics=[metrics.CategoricalAccuracy()]
)
history = model.fit(X_train, Y_train, epochs=epochs, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/40
# 2022-12-27 18:20:48.053821: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 19/19 [==============================] - ETA: 0s - loss: 0.9266 - categorical_accuracy: 0.7765
# 2022-12-27 18:20:49.828220: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 19/19 [==============================] - 2s 87ms/step - loss: 0.9266 - categorical_accuracy: 0.7765 - val_loss: 1.6328 - val_categorical_accuracy: 0.9079
# Epoch 2/40
# 19/19 [==============================] - 1s 65ms/step - loss: 0.3417 - categorical_accuracy: 0.9570 - val_loss: 1.5597 - val_categorical_accuracy: 0.8750
# Epoch 3/40
# 19/19 [==============================] - 1s 63ms/step - loss: 0.2425 - categorical_accuracy: 0.9652 - val_loss: 1.4945 - val_categorical_accuracy: 0.9342
# Epoch 4/40
# 19/19 [==============================] - 1s 61ms/step - loss: 0.1860 - categorical_accuracy: 0.9901 - val_loss: 1.4169 - val_categorical_accuracy: 0.9342
# Epoch 5/40
# 19/19 [==============================] - 1s 61ms/step - loss: 0.1699 - categorical_accuracy: 0.9801 - val_loss: 1.3018 - val_categorical_accuracy: 0.9539
# Epoch 6/40
# 19/19 [==============================] - 1s 61ms/step - loss: 0.1454 - categorical_accuracy: 0.9884 - val_loss: 1.2275 - val_categorical_accuracy: 0.9408
# Epoch 7/40
# 19/19 [==============================] - 1s 61ms/step - loss: 0.1341 - categorical_accuracy: 0.9851 - val_loss: 1.0643 - val_categorical_accuracy: 0.9803
# Epoch 8/40
# 19/19 [==============================] - 1s 61ms/step - loss: 0.1086 - categorical_accuracy: 0.9934 - val_loss: 0.9505 - val_categorical_accuracy: 0.9671
# Epoch 9/40
# 19/19 [==============================] - 1s 62ms/step - loss: 0.1052 - categorical_accuracy: 0.9901 - val_loss: 0.8258 - val_categorical_accuracy: 0.9605
# Epoch 10/40
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0964 - categorical_accuracy: 0.9934 - val_loss: 0.6748 - val_categorical_accuracy: 0.9868
# Epoch 11/40
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0912 - categorical_accuracy: 0.9917 - val_loss: 0.5417 - val_categorical_accuracy: 0.9803
# Epoch 12/40
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0851 - categorical_accuracy: 0.9967 - val_loss: 0.4705 - val_categorical_accuracy: 0.9868
# Epoch 13/40
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0713 - categorical_accuracy: 0.9967 - val_loss: 0.4161 - val_categorical_accuracy: 0.9605
# Epoch 14/40
# 19/19 [==============================] - 1s 69ms/step - loss: 0.0647 - categorical_accuracy: 0.9934 - val_loss: 0.3364 - val_categorical_accuracy: 0.9803
# Epoch 15/40
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0703 - categorical_accuracy: 0.9934 - val_loss: 0.2400 - val_categorical_accuracy: 0.9934
# Epoch 16/40
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0579 - categorical_accuracy: 0.9950 - val_loss: 0.2134 - val_categorical_accuracy: 0.9868
# Epoch 17/40
# 19/19 [==============================] - 1s 77ms/step - loss: 0.0550 - categorical_accuracy: 0.9983 - val_loss: 0.1844 - val_categorical_accuracy: 0.9934
# Epoch 18/40
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0557 - categorical_accuracy: 0.9950 - val_loss: 0.1325 - val_categorical_accuracy: 0.9934
# Epoch 19/40
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0480 - categorical_accuracy: 0.9983 - val_loss: 0.1212 - val_categorical_accuracy: 0.9934
# Epoch 20/40
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0484 - categorical_accuracy: 0.9950 - val_loss: 0.0941 - val_categorical_accuracy: 0.9934
# Epoch 21/40
# 19/19 [==============================] - 1s 72ms/step - loss: 0.0466 - categorical_accuracy: 0.9983 - val_loss: 0.0853 - val_categorical_accuracy: 0.9803
# Epoch 22/40
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0380 - categorical_accuracy: 0.9983 - val_loss: 0.0666 - val_categorical_accuracy: 0.9934
# Epoch 23/40
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0421 - categorical_accuracy: 1.0000 - val_loss: 0.0627 - val_categorical_accuracy: 0.9934
# Epoch 24/40
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0408 - categorical_accuracy: 0.9967 - val_loss: 0.0634 - val_categorical_accuracy: 0.9934
# Epoch 25/40
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0321 - categorical_accuracy: 1.0000 - val_loss: 0.0620 - val_categorical_accuracy: 0.9868
# Epoch 26/40
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0292 - categorical_accuracy: 1.0000 - val_loss: 0.0532 - val_categorical_accuracy: 0.9868
# Epoch 27/40
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0326 - categorical_accuracy: 0.9983 - val_loss: 0.0768 - val_categorical_accuracy: 0.9868
# Epoch 28/40
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0293 - categorical_accuracy: 0.9983 - val_loss: 0.0411 - val_categorical_accuracy: 0.9934
# Epoch 29/40
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0303 - categorical_accuracy: 0.9983 - val_loss: 0.0417 - val_categorical_accuracy: 0.9934
# Epoch 30/40
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0235 - categorical_accuracy: 1.0000 - val_loss: 0.0468 - val_categorical_accuracy: 0.9934
# Epoch 31/40
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0212 - categorical_accuracy: 1.0000 - val_loss: 0.0404 - val_categorical_accuracy: 0.9868
# Epoch 32/40
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0282 - categorical_accuracy: 0.9983 - val_loss: 0.0374 - val_categorical_accuracy: 0.9934
# Epoch 33/40
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0227 - categorical_accuracy: 1.0000 - val_loss: 0.0441 - val_categorical_accuracy: 0.9934
# Epoch 34/40
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0176 - categorical_accuracy: 1.0000 - val_loss: 0.0492 - val_categorical_accuracy: 0.9934
# Epoch 35/40
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0180 - categorical_accuracy: 0.9983 - val_loss: 0.0452 - val_categorical_accuracy: 0.9934
# Epoch 36/40
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0237 - categorical_accuracy: 0.9983 - val_loss: 0.0466 - val_categorical_accuracy: 0.9868
# Epoch 37/40
# 19/19 [==============================] - 1s 71ms/step - loss: 0.0148 - categorical_accuracy: 1.0000 - val_loss: 0.0420 - val_categorical_accuracy: 0.9934
# Epoch 38/40
# 19/19 [==============================] - 1s 77ms/step - loss: 0.0171 - categorical_accuracy: 1.0000 - val_loss: 0.0348 - val_categorical_accuracy: 0.9934
# Epoch 39/40
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0141 - categorical_accuracy: 1.0000 - val_loss: 0.0253 - val_categorical_accuracy: 1.0000
# Epoch 40/40
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0222 - categorical_accuracy: 0.9967 - val_loss: 0.0479 - val_categorical_accuracy: 0.9868

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(loc='upper right')

# %%
output = np.argmax(model.predict(X_test), axis=1).reshape(-1, 1)
assert(output.shape == (190, 1))
np.savetxt('competition_output.csv', output, delimiter=",")
# Out:
# 5/6 [========================>.....] - ETA: 0s
# 2022-12-27 18:21:38.283261: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 6/6 [==============================] - 0s 34ms/step
